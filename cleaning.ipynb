# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# - Clean the allstar csv

# %%
file='Resources/allstar.csv'

all_star_df=pd.read_csv(file)

# %%
#show the dataframe
all_star_df=all_star_df.rename(columns={'year':'year_'})

all_star_df=all_star_df.drop(columns=["game_num"])
all_star_df.head()
# Out:
#    player_id  year_       game_id team_id league_id   gp  starting_pos
# 0  gomezle01   1933  ALS193307060     NYA        AL  1.0           1.0
# 1  ferreri01   1933  ALS193307060     BOS        AL  1.0           2.0
# 2  gehrilo01   1933  ALS193307060     NYA        AL  1.0           3.0
# 3  gehrich01   1933  ALS193307060     DET        AL  1.0           4.0
# 4  dykesji01   1933  ALS193307060     CHA        AL  1.0           5.0

# %%
#replace na values with 0's for game played and started in the allstar game
all_star_df['gp']=all_star_df['gp'].fillna(0)
all_star_df['starting_pos']=all_star_df['starting_pos'].fillna(0)
all_star_df['game_id']=all_star_df["game_id"].fillna("NA")

# %%
#show the new all_star dataframe
all_star_df
# Out:
#       player_id  year_       game_id team_id league_id   gp  starting_pos
# 0     gomezle01   1933  ALS193307060     NYA        AL  1.0           1.0
# 1     ferreri01   1933  ALS193307060     BOS        AL  1.0           2.0
# 2     gehrilo01   1933  ALS193307060     NYA        AL  1.0           3.0
# 3     gehrich01   1933  ALS193307060     DET        AL  1.0           4.0
# 4     dykesji01   1933  ALS193307060     CHA        AL  1.0           5.0
# ...         ...    ...           ...     ...       ...  ...           ...
# 5064  boxbebr01   2015  NLS201507155     TBA        AL  0.0           0.0
# 5065  gordoal01   2015  NLS201507156     KCA        AL  0.0           0.0
# 5066  herreke01   2015  NLS201507157     KCA        AL  0.0           0.0
# 5067  cabremi01   2015  NLS201507158     DET        AL  0.0           0.0
# 5068   salech01   2015  NLS201507159     CHA        AL  0.0           0.0
#
# [5069 rows x 7 columns]

# %% [markdown]
# - Clean the batting csv

# %%
file='Resources/batting.csv'

batting_df=pd.read_csv(file)

# %%
#drop columns we don't need
batting_df=batting_df.drop(columns=['cs','hbp','sh','sf','g_idp','ibb'])

# %%
#replace na values with 0's for game played and started in the allstar game
batting_df['league_id']=batting_df['league_id'].fillna(0)
batting_df["ab"]=batting_df["ab"].fillna(0)
batting_df["r"]=batting_df["r"].fillna(0)
batting_df["h"]=batting_df["h"].fillna(0)
batting_df["double_"]=batting_df["double_"].fillna(0)
batting_df["triple"]=batting_df["triple"].fillna(0)
batting_df["hr"]=batting_df["hr"].fillna(0)
batting_df["rbi"]=batting_df["rbi"].fillna(0)
batting_df["sb"]=batting_df["sb"].fillna(0)
batting_df["bb"]=batting_df["bb"].fillna(0)
batting_df["so"]=batting_df["so"].fillna(0)

# %%
batting_df=batting_df.rename(columns={'year':'year_','g':'g_','double':'double_'})
batting_df
# Out:
#         player_id  year_  stint team_id league_id   g_     ab     r     h  \
# 0       abercda01   1871      1     TRO         0    1    4.0   0.0   0.0
# 1        addybo01   1871      1     RC1         0   25  118.0  30.0  32.0
# 2       allisar01   1871      1     CL1         0   29  137.0  28.0  40.0
# 3       allisdo01   1871      1     WS3         0   27  133.0  28.0  44.0
# 4       ansonca01   1871      1     RC1         0   25  120.0  29.0  39.0
# ...           ...    ...    ...     ...       ...  ...    ...   ...   ...
# 101327   zitoba01   2015      1     OAK        AL    3    0.0   0.0   0.0
# 101328  zobribe01   2015      1     OAK        AL   67  235.0  39.0  63.0
# 101329  zobribe01   2015      2     KCA        AL   59  232.0  37.0  66.0
# 101330  zuninmi01   2015      1     SEA        AL  112  350.0  28.0  61.0
# 101331   zychto01   2015      1     SEA        AL   13    0.0   0.0   0.0
#
#         double_  triple    hr   rbi   sb    bb     so
# ...

# %% [markdown]
# - Clean the batting csv

# %%
file='Resources/pitching.csv'

pitching_df=pd.read_csv(file)

# %%
pitching_df
# Out:
#        player_id  year  stint team_id league_id   w   l   g  gs  cg  ...  ibb  \
# 0      bechtge01  1871      1     PH1       NaN   1   2   3   3   2  ...  NaN
# 1      brainas01  1871      1     WS3       NaN  12  15  30  30  30  ...  NaN
# 2      fergubo01  1871      1     NY2       NaN   0   0   1   0   0  ...  NaN
# 3      fishech01  1871      1     RC1       NaN   4  16  24  24  22  ...  NaN
# 4      fleetfr01  1871      1     NY2       NaN   0   1   1   1   1  ...  NaN
# ...          ...   ...    ...     ...       ...  ..  ..  ..  ..  ..  ...  ...
# 44134  youngch03  2015      1     KCA        AL  11   6  34  18   0  ...  0.0
# 44135  zieglbr01  2015      1     ARI        NL   0   3  66   0   0  ...  3.0
# 44136  zimmejo02  2015      1     WAS        NL  13  10  33  33   0  ...  3.0
# 44137   zitoba01  2015      1     OAK        AL   0   0   3   2   0  ...  0.0
# 44138   zychto01  2015      1     SEA        AL   0   0  13   1   0  ...  0.0
#
# ...

# %%
pitching_df=pitching_df.drop(columns=['ipouts','baopp','ibb','wp','bk','bfp','gf','sf','g_idp','sh'])

# %%
pitching_df=pitching_df.rename(columns={'year':'year_','g':'g_'})

# %%
#replace na values with 0's for game played and started in the allstar game
pitching_df['league_id']=pitching_df['league_id'].fillna("None")
pitching_df['w']=pitching_df['w'].fillna(0)
pitching_df['w']=pitching_df['l'].fillna(0)
pitching_df['g_']=pitching_df['g_'].fillna(0)
pitching_df['gs']=pitching_df['gs'].fillna(0)
pitching_df['cg']=pitching_df['cg'].fillna(0)
pitching_df['sho']=pitching_df['sho'].fillna(0)
pitching_df['sv']=pitching_df['sv'].fillna(0)
pitching_df['h']=pitching_df['h'].fillna(0)
pitching_df['er']=pitching_df['er'].fillna(0)
pitching_df['hr']=pitching_df['hr'].fillna(0)
pitching_df['bb']=pitching_df['bb'].fillna(0)
pitching_df['so']=pitching_df['so'].fillna(0)
pitching_df['era']=pitching_df['era'].fillna(0)
pitching_df['hbp']=pitching_df['hbp'].fillna(0)

# %%
pitching_df
# Out:
#        player_id  year_  stint team_id league_id   w   l  g_  gs  cg  sho  sv  \
# 0      bechtge01   1871      1     PH1      None   2   2   3   3   2    0   0
# 1      brainas01   1871      1     WS3      None  15  15  30  30  30    0   0
# 2      fergubo01   1871      1     NY2      None   0   0   1   0   0    0   0
# 3      fishech01   1871      1     RC1      None  16  16  24  24  22    1   0
# 4      fleetfr01   1871      1     NY2      None   1   1   1   1   1    0   0
# ...          ...    ...    ...     ...       ...  ..  ..  ..  ..  ..  ...  ..
# 44134  youngch03   2015      1     KCA        AL   6   6  34  18   0    0   0
# 44135  zieglbr01   2015      1     ARI        NL   3   3  66   0   0    0  30
# 44136  zimmejo02   2015      1     WAS        NL  10  10  33  33   0    0   0
# 44137   zitoba01   2015      1     OAK        AL   0   0   3   2   0    0   0
# 44138   zychto01   2015      1     SEA        AL   0   0  13   1   0    0   0
#
# ...

# %%
batting_df.to_csv('clean_csv/clean_batting.csv')

# %%
all_star_df.to_csv('clean_csv/clean_allstar.csv')

# %%
pitching_df.to_csv('clean_csv/clean_pitching.csv')

# %%
rds_connection_string = "postgres:<password>@localhost:5432/baseball"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['team', 'player', 'pitching', 'batting', 'allstar']

# %%
all_star_df.to_sql(name='allstar', con=engine, if_exists='append', index=False)

# %%
batting_df.to_sql(name='batting', con=engine, if_exists='append', index=False)

# %%
pitching_df.to_sql(name='pitching', con=engine, if_exists='append', index=False)
